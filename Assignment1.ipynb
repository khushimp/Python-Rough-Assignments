# %%
#Assignment1

#LIST:
#make list of students
students = ["Aarav", "Isha", "Rohan", "Sneha", "Kabir"]
#display 3rd student's name
print("Third student:", students[2])
#Correct Rohan's name
students[2] = "Rohan Patil"
#Add two new students
students.append("Ananya")
students.append("Vihaan")
#Remove Kabir
students.remove("Kabir")
#Finding total number of students in list
print("Total registered students:", len(students))
#Check whether Isha is in the list
if "Isha" in students:
    print("Isha is registered.")
else:
    print("Isha is not registered.")
#Arrange the final list alphabetically
students.sort()
#Create a backup copy of list
backup_students = students.copy()
#create a 2nd list
hackathon = ["Meera", "Arjun", "Isha"]
#Combine both lists
all_participants = students + hackathon
#Display all the required lists
print("\nFinal Tech Fest list:", students)
print("Backup list:", backup_students)
print("Combined participant list:", all_participants)

print("\n")

#TUPLE:
#create a tuple for courses
courses = ("Python", "Data Science", "Cloud Computing", "Cyber Security", "AI")
#Display the second course
print("Second course:", courses[1])
# Display the last two courses of tuple
print("Last two courses:", courses[-2:])
#Check whether Python is present in tuple
if "Python" in courses:
    print("Python is present in the course list.")
else:
    print("Python is not present in the course list.")
#Find the index of Cloud Computing in the tuple
print("Index of Cloud Computing in tuple:", courses.index("Cloud Computing"))
#Find total number of courses
print("Total number of courses:", len(courses))
#create a new tuple with old and new courses in it
courses+= ("Machine Learning", "Web Development")
#Create a new tuple without Cyber Security by using a list
#courses = tuple(course for course in courses if course != "Cyber Security")
y = list(courses)
y.remove("Cyber Security")
courses = tuple(y)
#Arrange courses alphabetically by interconverting back from a list
sorted_courses = tuple(sorted(courses))
#Create a backup copy of courses tuple
backup_courses = sorted_courses
#create tuple for Friend's courses
friend_courses = ("AI", "Blockchain", "Python")
#Combine student's courses and friend's courses into a new tuple 
combined_courses = sorted_courses + friend_courses
# Display final results
print("\nFinal course tuple:", courses)
print("Sorted tuple:", sorted_courses)
print("Backup tuple:", backup_courses)
print("Combined tuple:", combined_courses)

print("\n")

#DICTIONARY:
#define dictionary
thisdict = {"brand": "Ford","model": "Mustang","year": 1964}
print(thisdict)
#access value of dictionary
x = thisdict.get("model")
x = thisdict.keys()
x = thisdict.values()
#update dictionary
thisdict = {"brand": "Ford","model": "Mustang","year": 1964}
thisdict["year"] = 2018
print(thisdict)
thisdict.update({"year": 2020})
print(thisdict)
#add to dictionary
thisdict.update({"battle": 1864})
print(thisdict)
#delete from dictionary
thisdict.pop("model")
print(thisdict)
thisdict.popitem()
print(thisdict)
# Out:
# Third student: Rohan
# Total registered students: 6
# Isha is registered.
#
# Final Tech Fest list: ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
# Backup list: ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
# Combined participant list: ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan', 'Meera', 'Arjun', 'Isha']
#
#
# Second course: Data Science
# Last two courses: ('Cyber Security', 'AI')
# Python is present in the course list.
# Index of Cloud Computing in tuple: 2
# Total number of courses: 5
#
# Final course tuple: ('Python', 'Data Science', 'Cloud Computing', 'AI', 'Machine Learning', 'Web Development')
# Sorted tuple: ('AI', 'Cloud Computing', 'Data Science', 'Machine Learning', 'Python', 'Web Development')
# Backup tuple: ('AI', 'Cloud Computing', 'Data Science', 'Machine Learning', 'Python', 'Web Development')
# ...
